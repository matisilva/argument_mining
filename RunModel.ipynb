# %% [markdown]
# # Ejemplo de uso de modelos entrenados.

# %%
from __future__ import print_function
import nltk
from util.preprocessing import addCharInformation, createMatrices, addCasingInformation
from neuralnets.BiLSTM import BiLSTM
import sys

# %% [markdown]
# # Carga de modelo preentrenado.

# %%
lstmModel = BiLSTM()
lstmModel.loadModel("models/am/AM_TAG/am_cnn_clstm_0.4635_0.6809_20.h5")

# %% [markdown]
# # Carga de texto de prueba "test_.txt"

# %%
with open("test_.txt", 'r') as f:
    text = f.read()
    if len(text.split("\t"))>1:
        os.system('python util/conll_to_txt.py --input={} --output={}_txt --target_column={}'.format("test_.txt","test_.txt",1))
        with open("test_.txt_txt", 'r') as newf:
            text = newf.read()
text[:1000]
# Out:
# 'International tourism is now more common than ever before The last 50 years have seen a significant increase in the number of tourist traveling worldwide . While some might think the tourism bring large profit for the destination countries , I would contend that this industry has affected the cultural attributes and damaged the natural environment of the tourist destinations . Firstly , it is an undeniable fact that tourists from different cultures will probably cause changes to the cultural identity of the tourist destinations . Take Thailand for example , in the Vietnam War , many American soldiers came to Thailand for a break and involved in sexual and drug activities , these huge demands caused many local businesses opened and expanded , even illegally involved in under - age prostitutes to maximize their profits . This was due to the lack of adequate controls by authorities and lead to a bad image of Thailand tourism . Therefore this proves that international tourism can create ne'

# %% [markdown]
# # Preparación previa de nuestro texto a evaluar

# %%
paragraphs = filter(lambda x: x != '', text.splitlines())
sentences = [{'tokens': nltk.word_tokenize(par)} for par in paragraphs]
sentences[0]
# Out:
# {'tokens': ['International',
#   'tourism',
#   'is',
#   'now',
#   'more',
#   'common',
#   'than',
#   'ever',
#   'before',
#   'The',
#   'last',
#   '50',
#   'years',
#   'have',
#   'seen',
#   'a',
#   'significant',
#   'increase',
#   'in',
#   'the',
#   'number',
#   'of',
#   'tourist',
#   'traveling',
#   'worldwide',
#   '.',
#   'While',
#   'some',
#   'might',
#   'think',
#   'the',
#   'tourism',
#   'bring',
#   'large',
#   'profit',
#   'for',
#   'the',
#   'destination',
#   'countries',
#   ',',
#   'I',
#   'would',
#   'contend',
#   'that',
#   'this',
#   'industry',
#   'has',
#   'affected',
#   'the',
#   'cultural',
#   'attributes',
#   'and',
#   'damaged',
#   'the',
#   'natural',
#   'environment',
#   'of',
#   'the',
#   'tourist',
#   'destinations',
#   '.',
#   'Firstly',
#   ',',
#   'it',
#   'is',
#   'an',
#   'undeniable',
#   'fact',
#   'that',
#   'tourists',
#   'from',
#   'different',
#   'cultures',
#   'will',
#   'probably',
#   'cause',
#   'changes',
#   'to',
#   'the',
#   'cultural',
#   'identity',
#   'of',
#   'the',
#   'tourist',
#   'destinations',
#   '.',
#   'Take',
#   'Thailand',
#   'for',
#   'example',
#   ',',
#   'in',
#   'the',
#   'Vietnam',
#   'War',
#   ',',
#   'many',
#   'American',
#   'soldiers',
#   'came',
#   'to',
#   'Thailand',
#   'for',
#   'a',
#   'break',
#   'and',
#   'involved',
#   'in',
#   'sexual',
#   'and',
#   'drug',
#   'activities',
#   ',',
#   'these',
#   'huge',
#   'demands',
#   'caused',
#   'many',
#   'local',
#   'businesses',
#   'opened',
#   'and',
#   'expanded',
#   ',',
#   'even',
#   'illegally',
#   'involved',
#   'in',
#   'under',
#   '-',
#   'age',
#   'prostitutes',
#   'to',
#   'maximize',
#   'their',
#   'profits',
#   '.',
#   'This',
#   'was',
#   'due',
#   'to',
#   'the',
#   'lack',
#   'of',
#   'adequate',
#   'controls',
#   'by',
#   'authorities',
#   'and',
#   'lead',
#   'to',
#   'a',
#   'bad',
#   'image',
#   'of',
#   'Thailand',
#   'tourism',
#   '.',
#   'Therefore',
#   'this',
#   'proves',
#   'that',
#   'international',
#   'tourism',
#   'can',
#   'create',
#   'negative',
#   'impacts',
#   'on',
#   'the',
#   'destination',
#   'countries',
#   '.',
#   'Secondly',
#   ',',
#   'there',
#   'are',
#   'clear',
#   'evidences',
#   'that',
#   'tourism',
#   'increasingly',
#   'create',
#   'harms',
#   'to',
#   'the',
#   'natural',
#   'habitats',
#   'of',
#   'the',
#   'destination',
#   'appeals',
#   '.',
#   'As',
#   'the',
#   'Australia',
#   '\xe2\x80\x99',
#   's',
#   'Great',
#   'Barrier',
#   'Reef',
#   'has',
#   'shown',
#   ',',
#   'the',
#   'billion',
#   'visitors',
#   'per',
#   'annum',
#   'has',
#   'generated',
#   'immense',
#   'destruction',
#   'to',
#   'this',
#   'nature',
#   'wonder',
#   ',',
#   'namely',
#   'breaking',
#   'the',
#   'corals',
#   'caused',
#   'by',
#   'walking',
#   'or',
#   'throwing',
#   'boat',
#   '\xe2\x80\x99',
#   's',
#   'anchors',
#   ',',
#   'dropping',
#   'fuel',
#   'and',
#   'other',
#   'sorts',
#   'of',
#   'pollutions',
#   '.',
#   'For',
#   'this',
#   'reason',
#   ',',
#   'many',
#   'marine',
#   'lives',
#   'have',
#   'been',
#   'endangered',
#   ',',
#   'in',
#   'the',
#   'extremes',
#   'part',
#   'of',
#   'the',
#   'reef',
#   'become',
#   'uninhabitable',
#   'for',
#   'these',
#   'marine',
#   'species',
#   '.',
#   'Thus',
#   ',',
#   'it',
#   'is',
#   'apparent',
#   'that',
#   'tourism',
#   'has',
#   'threatened',
#   'the',
#   'nature',
#   'environments',
#   '.',
#   'To',
#   'conclude',
#   ',',
#   'I',
#   'strongly',
#   'believe',
#   'that',
#   'the',
#   'tourism',
#   'has',
#   'created',
#   'threatening',
#   'pressure',
#   'on',
#   'both',
#   'the',
#   'sociocultural',
#   'and',
#   'natural',
#   'environments',
#   '.',
#   'If',
#   'authorities',
#   'do',
#   'not',
#   'take',
#   'steps',
#   'to',
#   'appropriately',
#   'conserve',
#   'these',
#   'precious',
#   'values',
#   ',',
#   'they',
#   'will',
#   'be',
#   'destroyed',
#   'in',
#   'the',
#   'near',
#   'future',
#   '.']}

# %%
addCharInformation(sentences)
addCasingInformation(sentences)
sentences[0]
# Out:
# {'casing': ['initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'initialUpper',
#   'allLower',
#   'numeric',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'initialUpper',
#   'initialUpper',
#   'other',
#   'allLower',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'initialUpper',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'initialUpper',
#   'other',
#   'allLower',
#   'initialUpper',
#   'initialUpper',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'other',
#   'allUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'initialUpper',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'allLower',
#   'other'],
#  'characters': [['I',
#    'n',
#    't',
#    'e',
#    'r',
#    'n',
#    'a',
#    't',
#    'i',
#    'o',
#    'n',
#    'a',
#    'l'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['i', 's'],
#   ['n', 'o', 'w'],
#   ['m', 'o', 'r', 'e'],
#   ['c', 'o', 'm', 'm', 'o', 'n'],
#   ['t', 'h', 'a', 'n'],
#   ['e', 'v', 'e', 'r'],
#   ['b', 'e', 'f', 'o', 'r', 'e'],
#   ['T', 'h', 'e'],
#   ['l', 'a', 's', 't'],
#   ['5', '0'],
#   ['y', 'e', 'a', 'r', 's'],
#   ['h', 'a', 'v', 'e'],
#   ['s', 'e', 'e', 'n'],
#   ['a'],
#   ['s', 'i', 'g', 'n', 'i', 'f', 'i', 'c', 'a', 'n', 't'],
#   ['i', 'n', 'c', 'r', 'e', 'a', 's', 'e'],
#   ['i', 'n'],
#   ['t', 'h', 'e'],
#   ['n', 'u', 'm', 'b', 'e', 'r'],
#   ['o', 'f'],
#   ['t', 'o', 'u', 'r', 'i', 's', 't'],
#   ['t', 'r', 'a', 'v', 'e', 'l', 'i', 'n', 'g'],
#   ['w', 'o', 'r', 'l', 'd', 'w', 'i', 'd', 'e'],
#   ['.'],
#   ['W', 'h', 'i', 'l', 'e'],
#   ['s', 'o', 'm', 'e'],
#   ['m', 'i', 'g', 'h', 't'],
#   ['t', 'h', 'i', 'n', 'k'],
#   ['t', 'h', 'e'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['b', 'r', 'i', 'n', 'g'],
#   ['l', 'a', 'r', 'g', 'e'],
#   ['p', 'r', 'o', 'f', 'i', 't'],
#   ['f', 'o', 'r'],
#   ['t', 'h', 'e'],
#   ['d', 'e', 's', 't', 'i', 'n', 'a', 't', 'i', 'o', 'n'],
#   ['c', 'o', 'u', 'n', 't', 'r', 'i', 'e', 's'],
#   [','],
#   ['I'],
#   ['w', 'o', 'u', 'l', 'd'],
#   ['c', 'o', 'n', 't', 'e', 'n', 'd'],
#   ['t', 'h', 'a', 't'],
#   ['t', 'h', 'i', 's'],
#   ['i', 'n', 'd', 'u', 's', 't', 'r', 'y'],
#   ['h', 'a', 's'],
#   ['a', 'f', 'f', 'e', 'c', 't', 'e', 'd'],
#   ['t', 'h', 'e'],
#   ['c', 'u', 'l', 't', 'u', 'r', 'a', 'l'],
#   ['a', 't', 't', 'r', 'i', 'b', 'u', 't', 'e', 's'],
#   ['a', 'n', 'd'],
#   ['d', 'a', 'm', 'a', 'g', 'e', 'd'],
#   ['t', 'h', 'e'],
#   ['n', 'a', 't', 'u', 'r', 'a', 'l'],
#   ['e', 'n', 'v', 'i', 'r', 'o', 'n', 'm', 'e', 'n', 't'],
#   ['o', 'f'],
#   ['t', 'h', 'e'],
#   ['t', 'o', 'u', 'r', 'i', 's', 't'],
#   ['d', 'e', 's', 't', 'i', 'n', 'a', 't', 'i', 'o', 'n', 's'],
#   ['.'],
#   ['F', 'i', 'r', 's', 't', 'l', 'y'],
#   [','],
#   ['i', 't'],
#   ['i', 's'],
#   ['a', 'n'],
#   ['u', 'n', 'd', 'e', 'n', 'i', 'a', 'b', 'l', 'e'],
#   ['f', 'a', 'c', 't'],
#   ['t', 'h', 'a', 't'],
#   ['t', 'o', 'u', 'r', 'i', 's', 't', 's'],
#   ['f', 'r', 'o', 'm'],
#   ['d', 'i', 'f', 'f', 'e', 'r', 'e', 'n', 't'],
#   ['c', 'u', 'l', 't', 'u', 'r', 'e', 's'],
#   ['w', 'i', 'l', 'l'],
#   ['p', 'r', 'o', 'b', 'a', 'b', 'l', 'y'],
#   ['c', 'a', 'u', 's', 'e'],
#   ['c', 'h', 'a', 'n', 'g', 'e', 's'],
#   ['t', 'o'],
#   ['t', 'h', 'e'],
#   ['c', 'u', 'l', 't', 'u', 'r', 'a', 'l'],
#   ['i', 'd', 'e', 'n', 't', 'i', 't', 'y'],
#   ['o', 'f'],
#   ['t', 'h', 'e'],
#   ['t', 'o', 'u', 'r', 'i', 's', 't'],
#   ['d', 'e', 's', 't', 'i', 'n', 'a', 't', 'i', 'o', 'n', 's'],
#   ['.'],
#   ['T', 'a', 'k', 'e'],
#   ['T', 'h', 'a', 'i', 'l', 'a', 'n', 'd'],
#   ['f', 'o', 'r'],
#   ['e', 'x', 'a', 'm', 'p', 'l', 'e'],
#   [','],
#   ['i', 'n'],
#   ['t', 'h', 'e'],
#   ['V', 'i', 'e', 't', 'n', 'a', 'm'],
#   ['W', 'a', 'r'],
#   [','],
#   ['m', 'a', 'n', 'y'],
#   ['A', 'm', 'e', 'r', 'i', 'c', 'a', 'n'],
#   ['s', 'o', 'l', 'd', 'i', 'e', 'r', 's'],
#   ['c', 'a', 'm', 'e'],
#   ['t', 'o'],
#   ['T', 'h', 'a', 'i', 'l', 'a', 'n', 'd'],
#   ['f', 'o', 'r'],
#   ['a'],
#   ['b', 'r', 'e', 'a', 'k'],
#   ['a', 'n', 'd'],
#   ['i', 'n', 'v', 'o', 'l', 'v', 'e', 'd'],
#   ['i', 'n'],
#   ['s', 'e', 'x', 'u', 'a', 'l'],
#   ['a', 'n', 'd'],
#   ['d', 'r', 'u', 'g'],
#   ['a', 'c', 't', 'i', 'v', 'i', 't', 'i', 'e', 's'],
#   [','],
#   ['t', 'h', 'e', 's', 'e'],
#   ['h', 'u', 'g', 'e'],
#   ['d', 'e', 'm', 'a', 'n', 'd', 's'],
#   ['c', 'a', 'u', 's', 'e', 'd'],
#   ['m', 'a', 'n', 'y'],
#   ['l', 'o', 'c', 'a', 'l'],
#   ['b', 'u', 's', 'i', 'n', 'e', 's', 's', 'e', 's'],
#   ['o', 'p', 'e', 'n', 'e', 'd'],
#   ['a', 'n', 'd'],
#   ['e', 'x', 'p', 'a', 'n', 'd', 'e', 'd'],
#   [','],
#   ['e', 'v', 'e', 'n'],
#   ['i', 'l', 'l', 'e', 'g', 'a', 'l', 'l', 'y'],
#   ['i', 'n', 'v', 'o', 'l', 'v', 'e', 'd'],
#   ['i', 'n'],
#   ['u', 'n', 'd', 'e', 'r'],
#   ['-'],
#   ['a', 'g', 'e'],
#   ['p', 'r', 'o', 's', 't', 'i', 't', 'u', 't', 'e', 's'],
#   ['t', 'o'],
#   ['m', 'a', 'x', 'i', 'm', 'i', 'z', 'e'],
#   ['t', 'h', 'e', 'i', 'r'],
#   ['p', 'r', 'o', 'f', 'i', 't', 's'],
#   ['.'],
#   ['T', 'h', 'i', 's'],
#   ['w', 'a', 's'],
#   ['d', 'u', 'e'],
#   ['t', 'o'],
#   ['t', 'h', 'e'],
#   ['l', 'a', 'c', 'k'],
#   ['o', 'f'],
#   ['a', 'd', 'e', 'q', 'u', 'a', 't', 'e'],
#   ['c', 'o', 'n', 't', 'r', 'o', 'l', 's'],
#   ['b', 'y'],
#   ['a', 'u', 't', 'h', 'o', 'r', 'i', 't', 'i', 'e', 's'],
#   ['a', 'n', 'd'],
#   ['l', 'e', 'a', 'd'],
#   ['t', 'o'],
#   ['a'],
#   ['b', 'a', 'd'],
#   ['i', 'm', 'a', 'g', 'e'],
#   ['o', 'f'],
#   ['T', 'h', 'a', 'i', 'l', 'a', 'n', 'd'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['.'],
#   ['T', 'h', 'e', 'r', 'e', 'f', 'o', 'r', 'e'],
#   ['t', 'h', 'i', 's'],
#   ['p', 'r', 'o', 'v', 'e', 's'],
#   ['t', 'h', 'a', 't'],
#   ['i', 'n', 't', 'e', 'r', 'n', 'a', 't', 'i', 'o', 'n', 'a', 'l'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['c', 'a', 'n'],
#   ['c', 'r', 'e', 'a', 't', 'e'],
#   ['n', 'e', 'g', 'a', 't', 'i', 'v', 'e'],
#   ['i', 'm', 'p', 'a', 'c', 't', 's'],
#   ['o', 'n'],
#   ['t', 'h', 'e'],
#   ['d', 'e', 's', 't', 'i', 'n', 'a', 't', 'i', 'o', 'n'],
#   ['c', 'o', 'u', 'n', 't', 'r', 'i', 'e', 's'],
#   ['.'],
#   ['S', 'e', 'c', 'o', 'n', 'd', 'l', 'y'],
#   [','],
#   ['t', 'h', 'e', 'r', 'e'],
#   ['a', 'r', 'e'],
#   ['c', 'l', 'e', 'a', 'r'],
#   ['e', 'v', 'i', 'd', 'e', 'n', 'c', 'e', 's'],
#   ['t', 'h', 'a', 't'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['i', 'n', 'c', 'r', 'e', 'a', 's', 'i', 'n', 'g', 'l', 'y'],
#   ['c', 'r', 'e', 'a', 't', 'e'],
#   ['h', 'a', 'r', 'm', 's'],
#   ['t', 'o'],
#   ['t', 'h', 'e'],
#   ['n', 'a', 't', 'u', 'r', 'a', 'l'],
#   ['h', 'a', 'b', 'i', 't', 'a', 't', 's'],
#   ['o', 'f'],
#   ['t', 'h', 'e'],
#   ['d', 'e', 's', 't', 'i', 'n', 'a', 't', 'i', 'o', 'n'],
#   ['a', 'p', 'p', 'e', 'a', 'l', 's'],
#   ['.'],
#   ['A', 's'],
#   ['t', 'h', 'e'],
#   ['A', 'u', 's', 't', 'r', 'a', 'l', 'i', 'a'],
#   ['\xe2', '\x80', '\x99'],
#   ['s'],
#   ['G', 'r', 'e', 'a', 't'],
#   ['B', 'a', 'r', 'r', 'i', 'e', 'r'],
#   ['R', 'e', 'e', 'f'],
#   ['h', 'a', 's'],
#   ['s', 'h', 'o', 'w', 'n'],
#   [','],
#   ['t', 'h', 'e'],
#   ['b', 'i', 'l', 'l', 'i', 'o', 'n'],
#   ['v', 'i', 's', 'i', 't', 'o', 'r', 's'],
#   ['p', 'e', 'r'],
#   ['a', 'n', 'n', 'u', 'm'],
#   ['h', 'a', 's'],
#   ['g', 'e', 'n', 'e', 'r', 'a', 't', 'e', 'd'],
#   ['i', 'm', 'm', 'e', 'n', 's', 'e'],
#   ['d', 'e', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n'],
#   ['t', 'o'],
#   ['t', 'h', 'i', 's'],
#   ['n', 'a', 't', 'u', 'r', 'e'],
#   ['w', 'o', 'n', 'd', 'e', 'r'],
#   [','],
#   ['n', 'a', 'm', 'e', 'l', 'y'],
#   ['b', 'r', 'e', 'a', 'k', 'i', 'n', 'g'],
#   ['t', 'h', 'e'],
#   ['c', 'o', 'r', 'a', 'l', 's'],
#   ['c', 'a', 'u', 's', 'e', 'd'],
#   ['b', 'y'],
#   ['w', 'a', 'l', 'k', 'i', 'n', 'g'],
#   ['o', 'r'],
#   ['t', 'h', 'r', 'o', 'w', 'i', 'n', 'g'],
#   ['b', 'o', 'a', 't'],
#   ['\xe2', '\x80', '\x99'],
#   ['s'],
#   ['a', 'n', 'c', 'h', 'o', 'r', 's'],
#   [','],
#   ['d', 'r', 'o', 'p', 'p', 'i', 'n', 'g'],
#   ['f', 'u', 'e', 'l'],
#   ['a', 'n', 'd'],
#   ['o', 't', 'h', 'e', 'r'],
#   ['s', 'o', 'r', 't', 's'],
#   ['o', 'f'],
#   ['p', 'o', 'l', 'l', 'u', 't', 'i', 'o', 'n', 's'],
#   ['.'],
#   ['F', 'o', 'r'],
#   ['t', 'h', 'i', 's'],
#   ['r', 'e', 'a', 's', 'o', 'n'],
#   [','],
#   ['m', 'a', 'n', 'y'],
#   ['m', 'a', 'r', 'i', 'n', 'e'],
#   ['l', 'i', 'v', 'e', 's'],
#   ['h', 'a', 'v', 'e'],
#   ['b', 'e', 'e', 'n'],
#   ['e', 'n', 'd', 'a', 'n', 'g', 'e', 'r', 'e', 'd'],
#   [','],
#   ['i', 'n'],
#   ['t', 'h', 'e'],
#   ['e', 'x', 't', 'r', 'e', 'm', 'e', 's'],
#   ['p', 'a', 'r', 't'],
#   ['o', 'f'],
#   ['t', 'h', 'e'],
#   ['r', 'e', 'e', 'f'],
#   ['b', 'e', 'c', 'o', 'm', 'e'],
#   ['u', 'n', 'i', 'n', 'h', 'a', 'b', 'i', 't', 'a', 'b', 'l', 'e'],
#   ['f', 'o', 'r'],
#   ['t', 'h', 'e', 's', 'e'],
#   ['m', 'a', 'r', 'i', 'n', 'e'],
#   ['s', 'p', 'e', 'c', 'i', 'e', 's'],
#   ['.'],
#   ['T', 'h', 'u', 's'],
#   [','],
#   ['i', 't'],
#   ['i', 's'],
#   ['a', 'p', 'p', 'a', 'r', 'e', 'n', 't'],
#   ['t', 'h', 'a', 't'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['h', 'a', 's'],
#   ['t', 'h', 'r', 'e', 'a', 't', 'e', 'n', 'e', 'd'],
#   ['t', 'h', 'e'],
#   ['n', 'a', 't', 'u', 'r', 'e'],
#   ['e', 'n', 'v', 'i', 'r', 'o', 'n', 'm', 'e', 'n', 't', 's'],
#   ['.'],
#   ['T', 'o'],
#   ['c', 'o', 'n', 'c', 'l', 'u', 'd', 'e'],
#   [','],
#   ['I'],
#   ['s', 't', 'r', 'o', 'n', 'g', 'l', 'y'],
#   ['b', 'e', 'l', 'i', 'e', 'v', 'e'],
#   ['t', 'h', 'a', 't'],
#   ['t', 'h', 'e'],
#   ['t', 'o', 'u', 'r', 'i', 's', 'm'],
#   ['h', 'a', 's'],
#   ['c', 'r', 'e', 'a', 't', 'e', 'd'],
#   ['t', 'h', 'r', 'e', 'a', 't', 'e', 'n', 'i', 'n', 'g'],
#   ['p', 'r', 'e', 's', 's', 'u', 'r', 'e'],
#   ['o', 'n'],
#   ['b', 'o', 't', 'h'],
#   ['t', 'h', 'e'],
#   ['s', 'o', 'c', 'i', 'o', 'c', 'u', 'l', 't', 'u', 'r', 'a', 'l'],
#   ['a', 'n', 'd'],
#   ['n', 'a', 't', 'u', 'r', 'a', 'l'],
#   ['e', 'n', 'v', 'i', 'r', 'o', 'n', 'm', 'e', 'n', 't', 's'],
#   ['.'],
#   ['I', 'f'],
#   ['a', 'u', 't', 'h', 'o', 'r', 'i', 't', 'i', 'e', 's'],
#   ['d', 'o'],
#   ['n', 'o', 't'],
#   ['t', 'a', 'k', 'e'],
#   ['s', 't', 'e', 'p', 's'],
#   ['t', 'o'],
#   ['a', 'p', 'p', 'r', 'o', 'p', 'r', 'i', 'a', 't', 'e', 'l', 'y'],
#   ['c', 'o', 'n', 's', 'e', 'r', 'v', 'e'],
#   ['t', 'h', 'e', 's', 'e'],
#   ['p', 'r', 'e', 'c', 'i', 'o', 'u', 's'],
#   ['v', 'a', 'l', 'u', 'e', 's'],
#   [','],
#   ['t', 'h', 'e', 'y'],
#   ['w', 'i', 'l', 'l'],
#   ['b', 'e'],
#   ['d', 'e', 's', 't', 'r', 'o', 'y', 'e', 'd'],
#   ['i', 'n'],
#   ['t', 'h', 'e'],
#   ['n', 'e', 'a', 'r'],
#   ['f', 'u', 't', 'u', 'r', 'e'],
#   ['.']],
#  'tokens': ['International',
#   'tourism',
#   'is',
#   'now',
#   'more',
#   'common',
#   'than',
#   'ever',
#   'before',
#   'The',
#   'last',
#   '50',
#   'years',
#   'have',
#   'seen',
#   'a',
#   'significant',
#   'increase',
#   'in',
#   'the',
#   'number',
#   'of',
#   'tourist',
#   'traveling',
#   'worldwide',
#   '.',
#   'While',
#   'some',
#   'might',
#   'think',
#   'the',
#   'tourism',
#   'bring',
#   'large',
#   'profit',
#   'for',
#   'the',
#   'destination',
#   'countries',
#   ',',
#   'I',
#   'would',
#   'contend',
#   'that',
#   'this',
#   'industry',
#   'has',
#   'affected',
#   'the',
#   'cultural',
#   'attributes',
#   'and',
#   'damaged',
#   'the',
#   'natural',
#   'environment',
#   'of',
#   'the',
#   'tourist',
#   'destinations',
#   '.',
#   'Firstly',
#   ',',
#   'it',
#   'is',
#   'an',
#   'undeniable',
#   'fact',
#   'that',
#   'tourists',
#   'from',
#   'different',
#   'cultures',
#   'will',
#   'probably',
#   'cause',
#   'changes',
#   'to',
#   'the',
#   'cultural',
#   'identity',
#   'of',
#   'the',
#   'tourist',
#   'destinations',
#   '.',
#   'Take',
#   'Thailand',
#   'for',
#   'example',
#   ',',
#   'in',
#   'the',
#   'Vietnam',
#   'War',
#   ',',
#   'many',
#   'American',
#   'soldiers',
#   'came',
#   'to',
#   'Thailand',
#   'for',
#   'a',
#   'break',
#   'and',
#   'involved',
#   'in',
#   'sexual',
#   'and',
#   'drug',
#   'activities',
#   ',',
#   'these',
#   'huge',
#   'demands',
#   'caused',
#   'many',
#   'local',
#   'businesses',
#   'opened',
#   'and',
#   'expanded',
#   ',',
#   'even',
#   'illegally',
#   'involved',
#   'in',
#   'under',
#   '-',
#   'age',
#   'prostitutes',
#   'to',
#   'maximize',
#   'their',
#   'profits',
#   '.',
#   'This',
#   'was',
#   'due',
#   'to',
#   'the',
#   'lack',
#   'of',
#   'adequate',
#   'controls',
#   'by',
#   'authorities',
#   'and',
#   'lead',
#   'to',
#   'a',
#   'bad',
#   'image',
#   'of',
#   'Thailand',
#   'tourism',
#   '.',
#   'Therefore',
#   'this',
#   'proves',
#   'that',
#   'international',
#   'tourism',
#   'can',
#   'create',
#   'negative',
#   'impacts',
#   'on',
#   'the',
#   'destination',
#   'countries',
#   '.',
#   'Secondly',
#   ',',
#   'there',
#   'are',
#   'clear',
#   'evidences',
#   'that',
#   'tourism',
#   'increasingly',
#   'create',
#   'harms',
#   'to',
#   'the',
#   'natural',
#   'habitats',
#   'of',
#   'the',
#   'destination',
#   'appeals',
#   '.',
#   'As',
#   'the',
#   'Australia',
#   '\xe2\x80\x99',
#   's',
#   'Great',
#   'Barrier',
#   'Reef',
#   'has',
#   'shown',
#   ',',
#   'the',
#   'billion',
#   'visitors',
#   'per',
#   'annum',
#   'has',
#   'generated',
#   'immense',
#   'destruction',
#   'to',
#   'this',
#   'nature',
#   'wonder',
#   ',',
#   'namely',
#   'breaking',
#   'the',
#   'corals',
#   'caused',
#   'by',
#   'walking',
#   'or',
#   'throwing',
#   'boat',
#   '\xe2\x80\x99',
#   's',
#   'anchors',
#   ',',
#   'dropping',
#   'fuel',
#   'and',
#   'other',
#   'sorts',
#   'of',
#   'pollutions',
#   '.',
#   'For',
#   'this',
#   'reason',
#   ',',
#   'many',
#   'marine',
#   'lives',
#   'have',
#   'been',
#   'endangered',
#   ',',
#   'in',
#   'the',
#   'extremes',
#   'part',
#   'of',
#   'the',
#   'reef',
#   'become',
#   'uninhabitable',
#   'for',
#   'these',
#   'marine',
#   'species',
#   '.',
#   'Thus',
#   ',',
#   'it',
#   'is',
#   'apparent',
#   'that',
#   'tourism',
#   'has',
#   'threatened',
#   'the',
#   'nature',
#   'environments',
#   '.',
#   'To',
#   'conclude',
#   ',',
#   'I',
#   'strongly',
#   'believe',
#   'that',
#   'the',
#   'tourism',
#   'has',
#   'created',
#   'threatening',
#   'pressure',
#   'on',
#   'both',
#   'the',
#   'sociocultural',
#   'and',
#   'natural',
#   'environments',
#   '.',
#   'If',
#   'authorities',
#   'do',
#   'not',
#   'take',
#   'steps',
#   'to',
#   'appropriately',
#   'conserve',
#   'these',
#   'precious',
#   'values',
#   ',',
#   'they',
#   'will',
#   'be',
#   'destroyed',
#   'in',
#   'the',
#   'near',
#   'future',
#   '.']}

# %%
dataMatrix = createMatrices(sentences, lstmModel.mappings)
dataMatrix[0]
# Out:
# {u'AM_TAG': [],
#  u'casing': [6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   5,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   6,
#   4,
#   4,
#   1,
#   4,
#   4,
#   6,
#   6,
#   1,
#   4,
#   6,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   1,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   6,
#   1,
#   4,
#   6,
#   6,
#   6,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   1,
#   5,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1],
#  u'characters': [[47, 26, 32, 17, 30, 26, 13, 32, 21, 27, 26, 13, 24],
#   [32, 27, 33, 30, 21, 31, 25],
#   [21, 31],
#   [26, 27, 35],
#   [25, 27, 30, 17],
#   [15, 27, 25, 25, 27, 26],
#   [32, 20, 13, 26],
#   [17, 34, 17, 30],
#   [14, 17, 18, 27, 30, 17],
#   [58, 20, 17],
#   [24, 13, 31, 32],
#   [8, 3],
#   [37, 17, 13, 30, 31],
#   [20, 13, 34, 17],
#   [31, 17, 17, 26],
#   [13],
#   [31, 21, 19, 26, 21, 18, 21, 15, 13, 26, 32],
#   [21, 26, 15, 30, 17, 13, 31, 17],
#   [21, 26],
#   [32, 20, 17],
#   [26, 33, 25, 14, 17, 30],
#   [27, 18],
#   [32, 27, 33, 30, 21, 31, 32],
#   [32, 30, 13, 34, 17, 24, 21, 26, 19],
#   [35, 27, 30, 24, 16, 35, 21, 16, 17],
#   [65],
#   [61, 20, 21, 24, 17],
#   [31, 27, 25, 17],
#   [25, 21, 19, 20, 32],
#   [32, 20, 21, 26, 23],
#   [32, 20, 17],
#   [32, 27, 33, 30, 21, 31, 25],
#   [14, 30, 21, 26, 19],
#   [24, 13, 30, 19, 17],
#   [28, 30, 27, 18, 21, 32],
#   [18, 27, 30],
#   [32, 20, 17],
#   [16, 17, 31, 32, 21, 26, 13, 32, 21, 27, 26],
#   [15, 27, 33, 26, 32, 30, 21, 17, 31],
#   [66],
#   [47],
#   [35, 27, 33, 24, 16],
#   [15, 27, 26, 32, 17, 26, 16],
#   [32, 20, 13, 32],
#   [32, 20, 21, 31],
#   [21, 26, 16, 33, 31, 32, 30, 37],
#   [20, 13, 31],
#   [13, 18, 18, 17, 15, 32, 17, 16],
#   [32, 20, 17],
#   [15, 33, 24, 32, 33, 30, 13, 24],
#   [13, 32, 32, 30, 21, 14, 33, 32, 17, 31],
#   [13, 26, 16],
#   [16, 13, 25, 13, 19, 17, 16],
#   [32, 20, 17],
#   [26, 13, 32, 33, 30, 13, 24],
#   [17, 26, 34, 21, 30, 27, 26, 25, 17, 26, 32],
#   [27, 18],
#   [32, 20, 17],
#   [32, 27, 33, 30, 21, 31, 32],
#   [16, 17, 31, 32, 21, 26, 13, 32, 21, 27, 26, 31],
#   [65],
#   [44, 21, 30, 31, 32, 24, 37],
#   [66],
#   [21, 32],
#   [21, 31],
#   [13, 26],
#   [33, 26, 16, 17, 26, 21, 13, 14, 24, 17],
#   [18, 13, 15, 32],
#   [32, 20, 13, 32],
#   [32, 27, 33, 30, 21, 31, 32, 31],
#   [18, 30, 27, 25],
#   [16, 21, 18, 18, 17, 30, 17, 26, 32],
#   [15, 33, 24, 32, 33, 30, 17, 31],
#   [35, 21, 24, 24],
#   [28, 30, 27, 14, 13, 14, 24, 37],
#   [15, 13, 33, 31, 17],
#   [15, 20, 13, 26, 19, 17, 31],
#   [32, 27],
#   [32, 20, 17],
#   [15, 33, 24, 32, 33, 30, 13, 24],
#   [21, 16, 17, 26, 32, 21, 32, 37],
#   [27, 18],
#   [32, 20, 17],
#   [32, 27, 33, 30, 21, 31, 32],
#   [16, 17, 31, 32, 21, 26, 13, 32, 21, 27, 26, 31],
#   [65],
#   [58, 13, 23, 17],
#   [58, 20, 13, 21, 24, 13, 26, 16],
#   [18, 27, 30],
#   [17, 36, 13, 25, 28, 24, 17],
#   [66],
#   [21, 26],
#   [32, 20, 17],
#   [60, 21, 17, 32, 26, 13, 25],
#   [61, 13, 30],
#   [66],
#   [25, 13, 26, 37],
#   [39, 25, 17, 30, 21, 15, 13, 26],
#   [31, 27, 24, 16, 21, 17, 30, 31],
#   [15, 13, 25, 17],
#   [32, 27],
#   [58, 20, 13, 21, 24, 13, 26, 16],
#   [18, 27, 30],
#   [13],
#   [14, 30, 17, 13, 23],
#   [13, 26, 16],
#   [21, 26, 34, 27, 24, 34, 17, 16],
#   [21, 26],
#   [31, 17, 36, 33, 13, 24],
#   [13, 26, 16],
#   [16, 30, 33, 19],
#   [13, 15, 32, 21, 34, 21, 32, 21, 17, 31],
#   [66],
#   [32, 20, 17, 31, 17],
#   [20, 33, 19, 17],
#   [16, 17, 25, 13, 26, 16, 31],
#   [15, 13, 33, 31, 17, 16],
#   [25, 13, 26, 37],
#   [24, 27, 15, 13, 24],
#   [14, 33, 31, 21, 26, 17, 31, 31, 17, 31],
#   [27, 28, 17, 26, 17, 16],
#   [13, 26, 16],
#   [17, 36, 28, 13, 26, 16, 17, 16],
#   [66],
#   [17, 34, 17, 26],
#   [21, 24, 24, 17, 19, 13, 24, 24, 37],
#   [21, 26, 34, 27, 24, 34, 17, 16],
#   [21, 26],
#   [33, 26, 16, 17, 30],
#   [67],
#   [13, 19, 17],
#   [28, 30, 27, 31, 32, 21, 32, 33, 32, 17, 31],
#   [32, 27],
#   [25, 13, 36, 21, 25, 21, 38, 17],
#   [32, 20, 17, 21, 30],
#   [28, 30, 27, 18, 21, 32, 31],
#   [65],
#   [58, 20, 21, 31],
#   [35, 13, 31],
#   [16, 33, 17],
#   [32, 27],
#   [32, 20, 17],
#   [24, 13, 15, 23],
#   [27, 18],
#   [13, 16, 17, 29, 33, 13, 32, 17],
#   [15, 27, 26, 32, 30, 27, 24, 31],
#   [14, 37],
#   [13, 33, 32, 20, 27, 30, 21, 32, 21, 17, 31],
#   [13, 26, 16],
#   [24, 17, 13, 16],
#   [32, 27],
#   [13],
#   [14, 13, 16],
#   [21, 25, 13, 19, 17],
#   [27, 18],
#   [58, 20, 13, 21, 24, 13, 26, 16],
#   [32, 27, 33, 30, 21, 31, 25],
#   [65],
#   [58, 20, 17, 30, 17, 18, 27, 30, 17],
#   [32, 20, 21, 31],
#   [28, 30, 27, 34, 17, 31],
#   [32, 20, 13, 32],
#   [21, 26, 32, 17, 30, 26, 13, 32, 21, 27, 26, 13, 24],
#   [32, 27, 33, 30, 21, 31, 25],
#   [15, 13, 26],
#   [15, 30, 17, 13, 32, 17],
#   [26, 17, 19, 13, 32, 21, 34, 17],
#   [21, 25, 28, 13, 15, 32, 31],
#   [27, 26],
#   [32, 20, 17],
#   [16, 17, 31, 32, 21, 26, 13, 32, 21, 27, 26],
#   [15, 27, 33, 26, 32, 30, 21, 17, 31],
#   [65],
#   [57, 17, 15, 27, 26, 16, 24, 37],
#   [66],
#   [32, 20, 17, 30, 17],
#   [13, 30, 17],
#   [15, 24, 17, 13, 30],
#   [17, 34, 21, 16, 17, 26, 15, 17, 31],
#   [32, 20, 13, 32],
#   [32, 27, 33, 30, 21, 31, 25],
#   [21, 26, 15, 30, 17, 13, 31, 21, 26, 19, 24, 37],
#   [15, 30, 17, 13, 32, 17],
#   [20, 13, 30, 25, 31],
#   [32, 27],
#   [32, 20, 17],
#   [26, 13, 32, 33, 30, 13, 24],
#   [20, 13, 14, 21, 32, 13, 32, 31],
#   [27, 18],
#   [32, 20, 17],
#   [16, 17, 31, 32, 21, 26, 13, 32, 21, 27, 26],
#   [13, 28, 28, 17, 13, 24, 31],
#   [65],
#   [39, 31],
#   [32, 20, 17],
#   [39, 33, 31, 32, 30, 13, 24, 21, 13],
#   [1, 1, 1],
#   [31],
#   [45, 30, 17, 13, 32],
#   [40, 13, 30, 30, 21, 17, 30],
#   [56, 17, 17, 18],
#   [20, 13, 31],
#   [31, 20, 27, 35, 26],
#   [66],
#   [32, 20, 17],
#   [14, 21, 24, 24, 21, 27, 26],
#   [34, 21, 31, 21, 32, 27, 30, 31],
#   [28, 17, 30],
#   [13, 26, 26, 33, 25],
#   [20, 13, 31],
#   [19, 17, 26, 17, 30, 13, 32, 17, 16],
#   [21, 25, 25, 17, 26, 31, 17],
#   [16, 17, 31, 32, 30, 33, 15, 32, 21, 27, 26],
#   [32, 27],
#   [32, 20, 21, 31],
#   [26, 13, 32, 33, 30, 17],
#   [35, 27, 26, 16, 17, 30],
#   [66],
#   [26, 13, 25, 17, 24, 37],
#   [14, 30, 17, 13, 23, 21, 26, 19],
#   [32, 20, 17],
#   [15, 27, 30, 13, 24, 31],
#   [15, 13, 33, 31, 17, 16],
#   [14, 37],
#   [35, 13, 24, 23, 21, 26, 19],
#   [27, 30],
#   [32, 20, 30, 27, 35, 21, 26, 19],
#   [14, 27, 13, 32],
#   [1, 1, 1],
#   [31],
#   [13, 26, 15, 20, 27, 30, 31],
#   [66],
#   [16, 30, 27, 28, 28, 21, 26, 19],
#   [18, 33, 17, 24],
#   [13, 26, 16],
#   [27, 32, 20, 17, 30],
#   [31, 27, 30, 32, 31],
#   [27, 18],
#   [28, 27, 24, 24, 33, 32, 21, 27, 26, 31],
#   [65],
#   [44, 27, 30],
#   [32, 20, 21, 31],
#   [30, 17, 13, 31, 27, 26],
#   [66],
#   [25, 13, 26, 37],
#   [25, 13, 30, 21, 26, 17],
#   [24, 21, 34, 17, 31],
#   [20, 13, 34, 17],
#   [14, 17, 17, 26],
#   [17, 26, 16, 13, 26, 19, 17, 30, 17, 16],
#   [66],
#   [21, 26],
#   [32, 20, 17],
#   [17, 36, 32, 30, 17, 25, 17, 31],
#   [28, 13, 30, 32],
#   [27, 18],
#   [32, 20, 17],
#   [30, 17, 17, 18],
#   [14, 17, 15, 27, 25, 17],
#   [33, 26, 21, 26, 20, 13, 14, 21, 32, 13, 14, 24, 17],
#   [18, 27, 30],
#   [32, 20, 17, 31, 17],
#   [25, 13, 30, 21, 26, 17],
#   [31, 28, 17, 15, 21, 17, 31],
#   [65],
#   [58, 20, 33, 31],
#   [66],
#   [21, 32],
#   [21, 31],
#   [13, 28, 28, 13, 30, 17, 26, 32],
#   [32, 20, 13, 32],
#   [32, 27, 33, 30, 21, 31, 25],
#   [20, 13, 31],
#   [32, 20, 30, 17, 13, 32, 17, 26, 17, 16],
#   [32, 20, 17],
#   [26, 13, 32, 33, 30, 17],
#   [17, 26, 34, 21, 30, 27, 26, 25, 17, 26, 32, 31],
#   [65],
#   [58, 27],
#   [15, 27, 26, 15, 24, 33, 16, 17],
#   [66],
#   [47],
#   [31, 32, 30, 27, 26, 19, 24, 37],
#   [14, 17, 24, 21, 17, 34, 17],
#   [32, 20, 13, 32],
#   [32, 20, 17],
#   [32, 27, 33, 30, 21, 31, 25],
#   [20, 13, 31],
#   [15, 30, 17, 13, 32, 17, 16],
#   [32, 20, 30, 17, 13, 32, 17, 26, 21, 26, 19],
#   [28, 30, 17, 31, 31, 33, 30, 17],
#   [27, 26],
#   [14, 27, 32, 20],
#   [32, 20, 17],
#   [31, 27, 15, 21, 27, 15, 33, 24, 32, 33, 30, 13, 24],
#   [13, 26, 16],
#   [26, 13, 32, 33, 30, 13, 24],
#   [17, 26, 34, 21, 30, 27, 26, 25, 17, 26, 32, 31],
#   [65],
#   [47, 18],
#   [13, 33, 32, 20, 27, 30, 21, 32, 21, 17, 31],
#   [16, 27],
#   [26, 27, 32],
#   [32, 13, 23, 17],
#   [31, 32, 17, 28, 31],
#   [32, 27],
#   [13, 28, 28, 30, 27, 28, 30, 21, 13, 32, 17, 24, 37],
#   [15, 27, 26, 31, 17, 30, 34, 17],
#   [32, 20, 17, 31, 17],
#   [28, 30, 17, 15, 21, 27, 33, 31],
#   [34, 13, 24, 33, 17, 31],
#   [66],
#   [32, 20, 17, 37],
#   [35, 21, 24, 24],
#   [14, 17],
#   [16, 17, 31, 32, 30, 27, 37, 17, 16],
#   [21, 26],
#   [32, 20, 17],
#   [26, 17, 13, 30],
#   [18, 33, 32, 33, 30, 17],
#   [65]],
#  u'label': [],
#  'raw_tokens': ['International',
#   'tourism',
#   'is',
#   'now',
#   'more',
#   'common',
#   'than',
#   'ever',
#   'before',
#   'The',
#   'last',
#   '50',
#   'years',
#   'have',
#   'seen',
#   'a',
#   'significant',
#   'increase',
#   'in',
#   'the',
#   'number',
#   'of',
#   'tourist',
#   'traveling',
#   'worldwide',
#   '.',
#   'While',
#   'some',
#   'might',
#   'think',
#   'the',
#   'tourism',
#   'bring',
#   'large',
#   'profit',
#   'for',
#   'the',
#   'destination',
#   'countries',
#   ',',
#   'I',
#   'would',
#   'contend',
#   'that',
#   'this',
#   'industry',
#   'has',
#   'affected',
#   'the',
#   'cultural',
#   'attributes',
#   'and',
#   'damaged',
#   'the',
#   'natural',
#   'environment',
#   'of',
#   'the',
#   'tourist',
#   'destinations',
#   '.',
#   'Firstly',
#   ',',
#   'it',
#   'is',
#   'an',
#   'undeniable',
#   'fact',
#   'that',
#   'tourists',
#   'from',
#   'different',
#   'cultures',
#   'will',
#   'probably',
#   'cause',
#   'changes',
#   'to',
#   'the',
#   'cultural',
#   'identity',
#   'of',
#   'the',
#   'tourist',
#   'destinations',
#   '.',
#   'Take',
#   'Thailand',
#   'for',
#   'example',
#   ',',
#   'in',
#   'the',
#   'Vietnam',
#   'War',
#   ',',
#   'many',
#   'American',
#   'soldiers',
#   'came',
#   'to',
#   'Thailand',
#   'for',
#   'a',
#   'break',
#   'and',
#   'involved',
#   'in',
#   'sexual',
#   'and',
#   'drug',
#   'activities',
#   ',',
#   'these',
#   'huge',
#   'demands',
#   'caused',
#   'many',
#   'local',
#   'businesses',
#   'opened',
#   'and',
#   'expanded',
#   ',',
#   'even',
#   'illegally',
#   'involved',
#   'in',
#   'under',
#   '-',
#   'age',
#   'prostitutes',
#   'to',
#   'maximize',
#   'their',
#   'profits',
#   '.',
#   'This',
#   'was',
#   'due',
#   'to',
#   'the',
#   'lack',
#   'of',
#   'adequate',
#   'controls',
#   'by',
#   'authorities',
#   'and',
#   'lead',
#   'to',
#   'a',
#   'bad',
#   'image',
#   'of',
#   'Thailand',
#   'tourism',
#   '.',
#   'Therefore',
#   'this',
#   'proves',
#   'that',
#   'international',
#   'tourism',
#   'can',
#   'create',
#   'negative',
#   'impacts',
#   'on',
#   'the',
#   'destination',
#   'countries',
#   '.',
#   'Secondly',
#   ',',
#   'there',
#   'are',
#   'clear',
#   'evidences',
#   'that',
#   'tourism',
#   'increasingly',
#   'create',
#   'harms',
#   'to',
#   'the',
#   'natural',
#   'habitats',
#   'of',
#   'the',
#   'destination',
#   'appeals',
#   '.',
#   'As',
#   'the',
#   'Australia',
#   '\xe2\x80\x99',
#   's',
#   'Great',
#   'Barrier',
#   'Reef',
#   'has',
#   'shown',
#   ',',
#   'the',
#   'billion',
#   'visitors',
#   'per',
#   'annum',
#   'has',
#   'generated',
#   'immense',
#   'destruction',
#   'to',
#   'this',
#   'nature',
#   'wonder',
#   ',',
#   'namely',
#   'breaking',
#   'the',
#   'corals',
#   'caused',
#   'by',
#   'walking',
#   'or',
#   'throwing',
#   'boat',
#   '\xe2\x80\x99',
#   's',
#   'anchors',
#   ',',
#   'dropping',
#   'fuel',
#   'and',
#   'other',
#   'sorts',
#   'of',
#   'pollutions',
#   '.',
#   'For',
#   'this',
#   'reason',
#   ',',
#   'many',
#   'marine',
#   'lives',
#   'have',
#   'been',
#   'endangered',
#   ',',
#   'in',
#   'the',
#   'extremes',
#   'part',
#   'of',
#   'the',
#   'reef',
#   'become',
#   'uninhabitable',
#   'for',
#   'these',
#   'marine',
#   'species',
#   '.',
#   'Thus',
#   ',',
#   'it',
#   'is',
#   'apparent',
#   'that',
#   'tourism',
#   'has',
#   'threatened',
#   'the',
#   'nature',
#   'environments',
#   '.',
#   'To',
#   'conclude',
#   ',',
#   'I',
#   'strongly',
#   'believe',
#   'that',
#   'the',
#   'tourism',
#   'has',
#   'created',
#   'threatening',
#   'pressure',
#   'on',
#   'both',
#   'the',
#   'sociocultural',
#   'and',
#   'natural',
#   'environments',
#   '.',
#   'If',
#   'authorities',
#   'do',
#   'not',
#   'take',
#   'steps',
#   'to',
#   'appropriately',
#   'conserve',
#   'these',
#   'precious',
#   'values',
#   ',',
#   'they',
#   'will',
#   'be',
#   'destroyed',
#   'in',
#   'the',
#   'near',
#   'future',
#   '.'],
#  u'tokens': [444,
#   5023,
#   5,
#   314,
#   88,
#   823,
#   246,
#   1681,
#   367,
#   2,
#   484,
#   2024,
#   48,
#   16,
#   169,
#   8,
#   1365,
#   807,
#   41,
#   2,
#   70,
#   61,
#   6574,
#   4034,
#   2571,
#   3,
#   239,
#   102,
#   1191,
#   117,
#   2,
#   5023,
#   749,
#   545,
#   6289,
#   128,
#   2,
#   3560,
#   576,
#   4,
#   30,
#   107,
#   10956,
#   14,
#   26,
#   689,
#   20,
#   1776,
#   2,
#   2267,
#   5925,
#   6,
#   1619,
#   2,
#   1880,
#   1275,
#   61,
#   2,
#   6574,
#   7397,
#   3,
#   14522,
#   4,
#   17,
#   5,
#   25,
#   48095,
#   560,
#   14,
#   6141,
#   177,
#   505,
#   4092,
#   199,
#   1562,
#   643,
#   600,
#   10,
#   2,
#   2267,
#   2038,
#   61,
#   2,
#   6574,
#   7397,
#   3,
#   103,
#   5241,
#   128,
#   517,
#   4,
#   41,
#   2,
#   3541,
#   90,
#   4,
#   142,
#   279,
#   1287,
#   135,
#   10,
#   5241,
#   128,
#   8,
#   1097,
#   6,
#   316,
#   41,
#   4326,
#   6,
#   3001,
#   900,
#   4,
#   224,
#   4330,
#   3595,
#   591,
#   142,
#   577,
#   2870,
#   219,
#   6,
#   780,
#   4,
#   478,
#   18498,
#   316,
#   41,
#   3003,
#   189,
#   315,
#   16120,
#   10,
#   11239,
#   55,
#   8314,
#   3,
#   26,
#   7,
#   278,
#   10,
#   2,
#   792,
#   61,
#   9336,
#   3414,
#   202,
#   1836,
#   6,
#   426,
#   10,
#   8,
#   2120,
#   489,
#   61,
#   5241,
#   5023,
#   3,
#   2062,
#   26,
#   5682,
#   14,
#   444,
#   5023,
#   105,
#   434,
#   3816,
#   7957,
#   168,
#   2,
#   3560,
#   576,
#   3,
#   14007,
#   4,
#   82,
#   11,
#   1329,
#   22995,
#   14,
#   5023,
#   5844,
#   434,
#   22948,
#   10,
#   2,
#   1880,
#   6517,
#   61,
#   2,
#   3560,
#   6453,
#   3,
#   23,
#   2,
#   707,
#   1,
#   747,
#   633,
#   5488,
#   7750,
#   20,
#   417,
#   4,
#   2,
#   8676,
#   3473,
#   3883,
#   42786,
#   20,
#   2391,
#   14989,
#   3020,
#   10,
#   26,
#   978,
#   3587,
#   4,
#   8381,
#   3019,
#   2,
#   23326,
#   591,
#   202,
#   3307,
#   40,
#   4819,
#   2297,
#   1,
#   747,
#   13551,
#   4,
#   5896,
#   3164,
#   6,
#   76,
#   6617,
#   61,
#   1,
#   3,
#   128,
#   26,
#   521,
#   4,
#   142,
#   2613,
#   840,
#   16,
#   28,
#   6850,
#   4,
#   41,
#   2,
#   17136,
#   58,
#   61,
#   2,
#   7750,
#   125,
#   53939,
#   128,
#   224,
#   2613,
#   222,
#   3,
#   1451,
#   4,
#   17,
#   5,
#   5514,
#   14,
#   5023,
#   20,
#   2258,
#   2,
#   978,
#   5649,
#   3,
#   10,
#   6326,
#   4,
#   30,
#   4356,
#   401,
#   14,
#   2,
#   5023,
#   20,
#   122,
#   6276,
#   1616,
#   168,
#   263,
#   2,
#   85405,
#   6,
#   1880,
#   5649,
#   3,
#   153,
#   1836,
#   74,
#   32,
#   103,
#   2869,
#   10,
#   14751,
#   14211,
#   224,
#   13521,
#   2215,
#   4,
#   54,
#   199,
#   12,
#   722,
#   41,
#   2,
#   3280,
#   1021,
#   3]}

# %% [markdown]
# # Ahora si, usemos nuestro modelo para identificar argumentos

# %%
tags = lstmModel.tagSentences(dataMatrix)
tags[0]
# Out:
# [u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'O',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'O',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:Against',
#  u'Claim:Against',
#  u'Claim:Against',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'O',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'Premise:Support',
#  u'O',
#  u'O',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'O',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'MajorClaim',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'Claim:For',
#  u'O',
#  u'O',
#  u'Claim:For',
#  u'Claim:For',
#  u'O']

# %% [markdown]
# # Veamos los resultados

# %%
for sentenceIdx in range(len(sentences[:2])):
    tokens = sentences[sentenceIdx]['tokens']
    tokenTags = tags[sentenceIdx]
    for tokenIdx in range(len(tokens)):
        print("{}\t{}".format(tokens[tokenIdx], tokenTags[tokenIdx]))
    print("")
# Out:
# International	O
# tourism	O
# is	O
# now	O
# more	O
# common	O
# than	O
# ever	O
# before	O
# The	O
# last	O
# 50	O
# years	O
# have	O
# seen	O
# a	O
# significant	O
# increase	O
# in	O
# the	O
# number	O
# of	O
# tourist	O
# traveling	O
# worldwide	O
# .	O
# While	O
# some	O
# might	O
# think	O
# the	O
# tourism	O
# bring	O
# large	O
# profit	O
# for	O
# the	O
# destination	O
# countries	O
# ,	O
# I	O
# would	O
# contend	O
# that	O
# this	MajorClaim
# industry	MajorClaim
# has	MajorClaim
# affected	MajorClaim
# the	MajorClaim
# cultural	MajorClaim
# attributes	MajorClaim
# and	MajorClaim
# damaged	MajorClaim
# the	MajorClaim
# natural	MajorClaim
# environment	MajorClaim
# of	MajorClaim
# the	MajorClaim
# tourist	MajorClaim
# destinations	MajorClaim
# .	O
# Firstly	O
# ,	O
# it	O
# is	O
# an	O
# undeniable	O
# fact	O
# that	O
# tourists	Claim:For
# from	Claim:For
# different	Claim:For
# cultures	Claim:For
# will	Claim:For
# probably	Claim:For
# cause	Claim:For
# changes	Claim:For
# to	Claim:For
# the	Claim:For
# cultural	Claim:For
# identity	Claim:For
# of	Claim:For
# the	Claim:For
# tourist	Claim:For
# destinations	Claim:For
# .	O
# Take	Premise:Support
# Thailand	Premise:Support
# for	Premise:Support
# example	Premise:Support
# ,	Premise:Support
# in	Premise:Support
# the	Premise:Support
# Vietnam	Premise:Support
# War	Premise:Support
# ,	Premise:Support
# many	Premise:Support
# American	Premise:Support
# soldiers	Premise:Support
# came	Premise:Support
# to	Premise:Support
# Thailand	Premise:Support
# for	Premise:Support
# a	Premise:Support
# break	Premise:Support
# and	Premise:Support
# involved	Premise:Support
# in	Premise:Support
# sexual	Premise:Support
# and	Premise:Support
# drug	Premise:Support
# activities	Premise:Support
# ,	Premise:Support
# these	Premise:Support
# huge	Premise:Support
# demands	Premise:Support
# caused	Premise:Support
# many	Premise:Support
# local	Premise:Support
# businesses	Premise:Support
# opened	Premise:Support
# and	Premise:Support
# expanded	Premise:Support
# ,	Premise:Support
# even	Premise:Support
# illegally	Premise:Support
# involved	Premise:Support
# in	Premise:Support
# under	Premise:Support
# -	Premise:Support
# age	Premise:Support
# prostitutes	Premise:Support
# to	Premise:Support
# maximize	Premise:Support
# their	Premise:Support
# profits	Premise:Support
# .	O
# This	Premise:Support
# was	Premise:Support
# due	Premise:Support
# to	Premise:Support
# the	Premise:Support
# lack	Premise:Support
# of	Premise:Support
# adequate	Premise:Support
# controls	Premise:Support
# by	Premise:Support
# authorities	Premise:Support
# and	Premise:Support
# lead	Premise:Support
# to	Premise:Support
# a	Premise:Support
# bad	Premise:Support
# image	Premise:Support
# of	Premise:Support
# Thailand	Premise:Support
# tourism	Premise:Support
# .	O
# Therefore	O
# this	O
# proves	O
# that	O
# international	Claim:For
# tourism	Claim:For
# can	Claim:For
# create	Claim:For
# negative	Claim:For
# impacts	Claim:For
# on	Claim:For
# the	Claim:For
# destination	Claim:For
# countries	Claim:For
# .	O
# Secondly	O
# ,	O
# there	O
# are	O
# clear	O
# evidences	O
# that	O
# tourism	Claim:For
# increasingly	Claim:For
# create	Claim:For
# harms	Claim:For
# to	Claim:For
# the	Claim:Against
# natural	Claim:Against
# habitats	Claim:Against
# of	Claim:For
# the	Claim:For
# destination	Claim:For
# appeals	Claim:For
# .	O
# As	Premise:Support
# the	Premise:Support
# Australia	Premise:Support
# ’	Premise:Support
# s	Premise:Support
# Great	Premise:Support
# Barrier	Premise:Support
# Reef	Premise:Support
# has	Premise:Support
# shown	Premise:Support
# ,	Premise:Support
# the	Premise:Support
# billion	Premise:Support
# visitors	Premise:Support
# per	Premise:Support
# annum	Premise:Support
# has	Premise:Support
# generated	Premise:Support
# immense	Premise:Support
# destruction	Premise:Support
# to	Premise:Support
# this	Premise:Support
# nature	Premise:Support
# wonder	Premise:Support
# ,	Premise:Support
# namely	Premise:Support
# breaking	Premise:Support
# the	Premise:Support
# corals	Premise:Support
# caused	Premise:Support
# by	Premise:Support
# walking	Premise:Support
# or	Premise:Support
# throwing	Premise:Support
# boat	Premise:Support
# ’	Premise:Support
# s	Premise:Support
# anchors	Premise:Support
# ,	Premise:Support
# dropping	Premise:Support
# fuel	Premise:Support
# and	Premise:Support
# other	Premise:Support
# sorts	Premise:Support
# of	Premise:Support
# pollutions	Premise:Support
# .	O
# For	O
# this	O
# reason	O
# ,	O
# many	Premise:Support
# marine	Premise:Support
# lives	Premise:Support
# have	Premise:Support
# been	Premise:Support
# endangered	Premise:Support
# ,	Premise:Support
# in	Premise:Support
# the	Premise:Support
# extremes	Premise:Support
# part	Premise:Support
# of	Premise:Support
# the	Premise:Support
# reef	Premise:Support
# become	Premise:Support
# uninhabitable	Premise:Support
# for	Premise:Support
# these	Premise:Support
# marine	Premise:Support
# species	Premise:Support
# .	O
# Thus	O
# ,	O
# it	Claim:For
# is	Claim:For
# apparent	Claim:For
# that	O
# tourism	Claim:For
# has	Claim:For
# threatened	Claim:For
# the	Claim:For
# nature	Claim:For
# environments	Claim:For
# .	O
# To	O
# conclude	O
# ,	O
# I	O
# strongly	O
# believe	O
# that	O
# the	MajorClaim
# tourism	MajorClaim
# has	MajorClaim
# created	MajorClaim
# threatening	MajorClaim
# pressure	MajorClaim
# on	MajorClaim
# both	MajorClaim
# the	MajorClaim
# sociocultural	MajorClaim
# and	MajorClaim
# natural	MajorClaim
# environments	MajorClaim
# .	O
# If	Claim:For
# authorities	Claim:For
# do	Claim:For
# not	Claim:For
# take	Claim:For
# steps	Claim:For
# to	Claim:For
# appropriately	Claim:For
# conserve	Claim:For
# these	Claim:For
# precious	Claim:For
# values	Claim:For
# ,	Claim:For
# they	Claim:For
# will	Claim:For
# be	Claim:For
# destroyed	Claim:For
# in	O
# the	O
# near	Claim:For
# future	Claim:For
# .	O
#
# Living	O
# and	O
# studying	O
# overseas	O
# It	O
# is	O
# every	O
# student	O
# '	O
# s	O
# desire	O
# to	O
# study	O
# at	O
# a	O
# good	O
# university	O
# and	O
# experience	O
# a	O
# new	O
# environment	O
# .	O
# While	O
# some	O
# students	O
# study	O
# and	O
# live	O
# overseas	O
# to	O
# achieve	O
# this	O
# ,	O
# some	O
# prefer	O
# to	O
# study	O
# home	O
# because	O
# of	O
# the	O
# difficulties	O
# of	O
# living	O
# and	O
# studying	O
# overseas	O
# .	O
# In	O
# my	O
# opinion	O
# ,	O
# one	MajorClaim
# who	MajorClaim
# studies	MajorClaim
# overseas	MajorClaim
# will	MajorClaim
# gain	MajorClaim
# many	MajorClaim
# skills	MajorClaim
# throughout	MajorClaim
# this	MajorClaim
# experience	MajorClaim
# for	O
# several	O
# reasons	O
# .	O
# First	O
# ,	O
# studying	Claim:For
# at	Claim:For
# an	Claim:For
# overseas	Claim:For
# university	Claim:For
# gives	Claim:For
# individuals	Claim:For
# the	Claim:For
# opportunity	Claim:For
# to	Claim:For
# improve	Claim:For
# social	Claim:For
# skills	Claim:For
# by	Claim:For
# interacting	Claim:For
# and	Claim:For
# communicating	Claim:For
# with	Claim:For
# students	Claim:For
# from	Claim:For
# different	Claim:For
# origins	Claim:For
# and	Claim:For
# cultures	Claim:For
# .	O
# Compared	Premise:Support
# to	Premise:Support
# the	Premise:Support
# peers	Premise:Support
# studying	Premise:Support
# in	Premise:Support
# the	Premise:Support
# home	Premise:Support
# country	Premise:Support
# ,	Premise:Support
# it	Premise:Support
# will	Premise:Support
# be	Premise:Support
# more	Premise:Support
# likely	Premise:Support
# for	Premise:Support
# the	Premise:Support
# one	Premise:Support
# who	Premise:Support
# is	Premise:Support
# living	Premise:Support
# overseas	Premise:Support
# to	Premise:Support
# be	Premise:Support
# successful	Premise:Support
# in	Premise:Support
# adapting	Premise:Support
# himself	Premise:Support
# /	Premise:Support
# herself	Premise:Support
# into	Premise:Support
# new	Premise:Support
# environments	Premise:Support
# and	Premise:Support
# situations	Premise:Support
# in	Premise:Support
# life	Premise:Support
# .	O
# Second	O
# ,	O
# living	Claim:For
# and	Claim:For
# studying	Claim:For
# overseas	Claim:For
# is	Claim:For
# an	Claim:For
# irreplaceable	Claim:For
# experience	Claim:For
# when	Claim:For
# it	Claim:For
# comes	Claim:For
# to	Claim:For
# learn	Claim:For
# standing	Claim:For
# on	Claim:For
# your	Claim:For
# own	Claim:For
# feet	Claim:For
# .	O
# One	Premise:Support
# who	Premise:Support
# is	Premise:Support
# living	Premise:Support
# overseas	Premise:Support
# will	Premise:Support
# of	Premise:Support
# course	Premise:Support
# struggle	Premise:Support
# with	Premise:Support
# loneliness	Premise:Support
# ,	Premise:Support
# living	Premise:Support
# away	Premise:Support
# from	Premise:Support
# family	Premise:Support
# and	Premise:Support
# friends	Premise:Support
# but	Premise:Support
# those	Premise:Support
# difficulties	Premise:Support
# will	Premise:Support
# turn	Premise:Support
# into	Premise:Support
# valuable	Premise:Support
# experiences	Premise:Support
# in	Premise:Support
# the	Premise:Support
# following	Premise:Support
# steps	Premise:Support
# of	Premise:Support
# life	Premise:Support
# .	O
# Moreover	O
# ,	O
# the	Premise:Support
# one	Premise:Support
# will	Premise:Support
# learn	Premise:Support
# living	Premise:Support
# without	Premise:Support
# depending	Premise:Support
# on	Claim:For
# anyone	Claim:For
# else	Premise:Support
# .	O
# Also	O
# ,	O
# employers	Premise:Support
# are	Premise:Support
# mostly	Premise:Support
# looking	Premise:Support
# for	Premise:Support
# people	Premise:Support
# who	Premise:Support
# have	Premise:Support
# international	Premise:Support
# and	Premise:Support
# language	Premise:Support
# skills	Premise:Support
# .	O
# Becoming	Premise:Support
# successful	Premise:Support
# in	Premise:Support
# this	Premise:Support
# study	Premise:Support
# will	Premise:Support
# give	Premise:Support
# the	Premise:Support
# student	Premise:Support
# an	Premise:Support
# edge	Premise:Support
# in	Premise:Support
# job	Premise:Support
# market	Premise:Support
# .	O
# Therefore	O
# ,	O
# one	Premise:Support
# who	Premise:Support
# has	Premise:Support
# studied	Premise:Support
# and	Claim:For
# lived	Claim:For
# overseas	Claim:For
# will	Claim:For
# become	Claim:For
# more	Claim:For
# eligible	Claim:For
# for	Premise:Support
# the	Premise:Support
# job	Premise:Support
# than	Premise:Support
# his	Premise:Support
# /	Claim:For
# her	Claim:For
# peers	Claim:For
# .	O
# In	O
# conclusion	O
# ,	O
# there	MajorClaim
# are	MajorClaim
# many	MajorClaim
# difficulties	MajorClaim
# a	MajorClaim
# student	MajorClaim
# might	MajorClaim
# face	MajorClaim
# when	MajorClaim
# studying	MajorClaim
# and	MajorClaim
# living	MajorClaim
# overseas	MajorClaim
# .	O
# However	O
# ,	O
# living	MajorClaim
# and	O
# studying	O
# overseas	O
# gives	O
# the	O
# individual	O
# a	O
# new	O
# perspective	O
# on	O
# the	O
# subject	O
# that	O
# is	O
# studied	O
# or	O
# in	O
# general	O
# life	MajorClaim
# .	O
